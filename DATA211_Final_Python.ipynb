# %%
import matplotlib.pyplot as plt

# %%
labels = ['Feb 28','Mar 1','Mar 2','Mar 3','Mar 4','Mar 5','Mar 6']

# %%
loc_change = [9, 10, 7, 13, 7, 8, 6]
num_encounters = [9, 30, 22, 28, 14, 4, 9]
num_encounters_transit = [1,22,8,23,7,4,8]

# %%
plt.figure(figsize = [14,10])
plt.scatter(labels,loc_change, label='Location Changes',color='#e15759',linewidth=4)
plt.scatter(labels,num_encounters,label='Chance Encounters',color = '#76b7b2',linewidth=4)
plt.plot(labels,loc_change, label='',color='#e15759',linewidth=.5)
plt.plot(labels,num_encounters,label='',color = '#76b7b2',linewidth=.5)
#plt.plot(labels,num_encounters_transit,label='Chance Encounters While in Transit',color = '#76b7b2',linewidth=4)
plt.legend(fontsize=16,loc='upper right')
#plt.title('increasing')
plt.xlabel('Date',fontsize=20,labelpad=10)
plt.ylabel('Count',fontsize=20,labelpad=10)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tick_params(size=0,pad=10)
plt.grid(color='gainsboro')
plt.savefig('intransit.png')
plt.show()
